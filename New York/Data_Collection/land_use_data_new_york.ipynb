# %%
import geopandas as gpd
import pandas as pd
from shapely.geometry import Point
from rasterstats import zonal_stats

# %%
# Input file paths
raster_path = "Land_Cover/Land_Cover/NYC_2017_LiDAR_LandCover.img"
bike_data_csv = "processed_data_newyork_10042025.csv"
district_shp = "nycdwi_25a/nycdwi.shp"

# %%
# 2017 dataset class labels
class_labels_2017 = {
    1: "Tree Canopy",
    2: "Grass/Shrubs",
    3: "Bare Soil",
    4: "Water",
    5: "Buildings",
    6: "Roads",
    7: "Other Impervious",
    8: "Railroads"
}

# %%
# Load bike station CSV
bike_df = pd.read_csv(bike_data_csv)
unique_stations = bike_df[['name', 'longitude', 'latitude']].drop_duplicates()

# Convert to GeoDataFrame
geometry = [Point(xy) for xy in zip(unique_stations.longitude, unique_stations.latitude)]
station_gdf = gpd.GeoDataFrame(unique_stations, geometry=geometry, crs="EPSG:4326")
station_gdf = station_gdf.to_crs("EPSG:2263")  # Match NYC raster CRS

# %%
cd_gdf = gpd.read_file(district_shp).to_crs("EPSG:2263")

# Spatial join: add community district info
station_with_cd = gpd.sjoin(station_gdf, cd_gdf, how="left", predicate="within")
station_with_cd = station_with_cd.rename(columns={"BoroCD": "community_district"})

# %%
# Create 100 ft buffer around each station
station_with_cd["geometry"] = station_with_cd.geometry.buffer(100)

# Extract raster stats
stats = zonal_stats(
    station_with_cd,
    raster_path,
    stats=None,
    categorical=True,
    all_touched=True,
    nodata=None
)

# %%
# Parse stats into % per class
lc_df = []
for i, stat in enumerate(stats):
    total = sum(stat.values())
    result = {class_labels_2017.get(k, f"Class_{k}"): (v / total) * 100 for k, v in stat.items()}
    result["name"] = station_with_cd.iloc[i]["name"]
    result["community_district"] = station_with_cd.iloc[i]["community_district"]
    lc_df.append(result)

landcover_df = pd.DataFrame(lc_df)

# %%
# Add lat/lon back to results
final_df = station_with_cd[['name', 'longitude', 'latitude']].merge(landcover_df, on="name")

# %%
# Let's check the dataset
final_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19 entries, 0 to 18
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   name                19 non-null     object
#  1   longitude           19 non-null     float64
#  2   latitude            19 non-null     float64
#  3   Tree Canopy         16 non-null     float64
#  4   Grass/Shrubs        19 non-null     float64
#  5   Roads               18 non-null     float64
#  6   Other Impervious    19 non-null     float64
#  7   community_district  19 non-null     int32
#  8   Buildings           11 non-null     float64
#  9   Railroads           2 non-null      float64
#  10  Bare Soil           2 non-null      float64
#  11  Water               2 non-null      float64
# dtypes: float64(10), int32(1), object(1)
# memory usage: 1.8+ KB

# %%
final_df.head(19)
# Out:
#                                           name  longitude   latitude  \
# 0                         111th St at 50th Ave -73.852500  40.745630
# 1                          8th Ave at 50th St. -73.986120  40.762348
# 2                    Amsterdam Ave at 86th St. -73.975050  40.787700
# 3       Brooklyn Bridge Bicycle Path (Roadway) -74.004464  40.712656
# 4                    Brooklyn Bridge Bike Path -74.000990  40.709274
# 5                     Columbus Ave at 86th St. -73.975050  40.787700
# 6        Ed Koch Queensboro Bridge Shared Path -73.940450  40.751010
# 7                             Emmons Ave Bikes -73.930990  40.584100
# 8                                 Fountain Ave -73.862951  40.655606
# 9                            High Bridge Bikes -73.932070  40.842190
# 10  Kent Ave btw North 8th St and North 9th St -73.960930  40.720959
# 11                   Manhattan Bridge Ped Path -73.994950  40.714573
# 12                      Ocean Pkwy at Avenue J -73.970609  40.624303
# 13                                 Pelham Pkwy -73.856154  40.857669
# 14                          Prospect Park West -73.971382  40.671288
# 15                              Pulaski Bridge -73.951492  40.742563
# 16                         Staten Island Ferry -74.072075  40.643387
# 17               Williamsburg Bridge Bike Path -73.961450  40.710530
# 18                            Willis Ave Bikes -73.924393  40.807046
#
#     Tree Canopy  Grass/Shrubs      Roads  Other Impervious  \
# 0     26.826757      6.629865  37.936988         28.606390
# 1      1.783522      0.856122  55.142674         21.418106
# 2      1.706836      0.949650  62.307832         24.484979
# 3     14.005877      2.145001  29.213367         45.889407
# 4      0.209082      0.372230  71.953653         27.465034
# 5      1.706836      0.949650  62.307832         24.484979
# 6      6.753150      1.190335  46.362074         23.748089
# 7     17.324537     46.809117  24.734291          9.404749
# 8     10.174713     21.709276  52.607236          7.736964
# 9     68.906119     17.666672        NaN         13.427209
# 10     8.104640      3.305059  36.883915         27.730653
# 11    14.226876      1.776577  42.759833         26.603514
# 12    23.195786      4.935847  55.447489         16.420878
# 13    19.925393      9.927056  52.467508         17.680044
# 14    40.014891      1.033639  28.019136         15.187758
# 15          NaN      1.336164  71.344163         18.356210
# 16          NaN      0.236820  29.162970         34.127487
# 17          NaN      0.278777  58.791757         23.003817
# 18     6.437792     11.003405  61.443732         21.115071
#
#     community_district  Buildings  Railroads  Bare Soil     Water
# 0                  481        NaN        NaN        NaN       NaN
# 1                  104  20.799576        NaN        NaN       NaN
# 2                  107  10.550702        NaN        NaN       NaN
# 3                  101   8.746346        NaN        NaN       NaN
# 4                  101        NaN        NaN        NaN       NaN
# 5                  107  10.550702        NaN        NaN       NaN
# 6                  402  17.809087   4.137265        NaN       NaN
# 7                  315        NaN        NaN   1.727306       NaN
# 8                  305        NaN        NaN   2.162928  5.608883
# 9                  112        NaN        NaN        NaN       NaN
# 10                 301  23.975733        NaN        NaN       NaN
# 11                 103  14.633200        NaN        NaN       NaN
# 12                 312        NaN        NaN        NaN       NaN
# 13                 211        NaN        NaN        NaN       NaN
# 14                 306  15.744576        NaN        NaN       NaN
# 15                 402   8.963463        NaN        NaN       NaN
# 16                 501  36.128976        NaN        NaN  0.343746
# 17                 301   5.967561  11.958088        NaN       NaN
# 18                 201        NaN        NaN        NaN       NaN

# %%
# Here, missing means 0% coverage for that class
final_df.fillna(0, inplace=True)

# %%
final_df.head(19)
# Out:
#                                           name  longitude   latitude  \
# 0                         111th St at 50th Ave -73.852500  40.745630
# 15                 402   8.963463   0.000000   0.000000  0.000000
# 16                 501  36.128976   0.000000   0.000000  0.343746
# 17                 301   5.967561  11.958088   0.000000  0.000000
# 18                 201   0.000000   0.000000   0.000000  0.000000

# %%
# Drop community district from land cover DataFrame
final_df = final_df.drop(columns=["community_district", "latitude", "longitude"])

# Merge with the cycling dataset
final_bike_df = bike_df.merge(final_df, on="name", how="left")

# And, save the file
final_bike_df.to_csv("processed_data_newyork_15042025.csv", index=False)

# %%
final_bike_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36461 entries, 0 to 36460
# Data columns (total 52 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   name                       36461 non-null  object
#  1   date                       36461 non-null  object
#  2   latitude                   36461 non-null  float64
#  3   longitude                  36461 non-null  float64
#  4   counts                     36461 non-null  int64
#  5   year                       36461 non-null  int64
#  6   distance_to_center_km      36461 non-null  float64
#  7   maxspeed_near_station      36461 non-null  float64
#  8   shops_within_0km           36461 non-null  int64
#  9   shops_within_1km           36461 non-null  int64
#  10  shops_within_2km           36461 non-null  int64
#  11  shops_within_5km           36461 non-null  int64
#  12  hotels_within_0km          36461 non-null  int64
#  13  hotels_within_1km          36461 non-null  int64
#  14  hotels_within_2km          36461 non-null  int64
#  15  hotels_within_5km          36461 non-null  int64
#  16  education_within_0km       36461 non-null  int64
#  17  education_within_1km       36461 non-null  int64
#  18  education_within_2km       36461 non-null  int64
#  19  education_within_5km       36461 non-null  int64
#  20  hospitals_within_0km       36461 non-null  int64
#  21  hospitals_within_1km       36461 non-null  int64
#  22  hospitals_within_2km       36461 non-null  int64
#  23  hospitals_within_5km       36461 non-null  int64
#  24  tavg                       36461 non-null  float64
#  25  tmin                       36461 non-null  float64
#  26  tmax                       36461 non-null  float64
#  27  prcp                       36461 non-null  float64
#  28  snow                       36461 non-null  float64
#  29  wspd                       36461 non-null  float64
#  30  pres                       36461 non-null  float64
#  31  wdir                       36461 non-null  float64
#  32  public_holiday             36461 non-null  int64
#  33  avg_motor_volume           36461 non-null  float64
#  34  total_motor_volume         36461 non-null  float64
#  35  city_avg_motor_volume      36461 non-null  float64
#  36  city_total_motor_volume    36461 non-null  float64
#  37  day_of_week                36461 non-null  int64
#  38  is_weekend                 36461 non-null  int64
#  39  month                      36461 non-null  int64
#  40  bicycle_lane_type_lane     36461 non-null  int64
#  41  bicycle_lane_type_none     36461 non-null  int64
#  42  bicycle_lane_type_track    36461 non-null  int64
#  43  bicycle_lane_type_unknown  36461 non-null  int64
#  44  Tree Canopy                36461 non-null  float64
#  45  Grass/Shrubs               36461 non-null  float64
#  46  Roads                      36461 non-null  float64
#  47  Other Impervious           36461 non-null  float64
#  48  Buildings                  36461 non-null  float64
#  49  Railroads                  36461 non-null  float64
#  50  Bare Soil                  36461 non-null  float64
#  51  Water                      36461 non-null  float64
# dtypes: float64(24), int64(26), object(2)
# memory usage: 14.5+ MB
